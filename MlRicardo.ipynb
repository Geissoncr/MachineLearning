# %%
import numpy as np
import pandas as pd
#from numpy import genfromtxt
import sklearn 
df = pd.read_csv('featv1.csv', sep=',',header=None)
dt = np.genfromtxt('featv1.csv', dtype=None, delimiter=',')
dt[2:3]
# Out:
# C:\Users\PoRtelA\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# ...

# %%
caracteristicas = dt[1:,0:826]
nomes_caracteristicas = dt[0,:826]
classificacao = dt[1:,827]
nomes_classificao = 'class'
print(dt[1:,827])
# Out:
# [4.07000000e-05 9.16000000e-05 2.74658000e-04 3.76383000e-04
#  6.51042000e-04 1.45467100e-03 2.54313200e-03 4.29280600e-03
#  6.64266000e-03 9.02303100e-03 1.12609860e-02 1.43330890e-02
#  1.74357100e-02 1.90327960e-02 2.00500490e-02 1.93176270e-02
#  1.99788410e-02 1.76391600e-02 1.67439780e-02 1.53910320e-02
#  1.42618820e-02 1.37837730e-02 1.25834150e-02 1.22578940e-02
#  1.23189290e-02 1.33361820e-02 1.35599770e-02 1.94396970e-02
#  2.66621910e-02 2.40885420e-02 1.99076330e-02 2.21252440e-02
#  1.23494470e-02 8.03629600e-03 7.46663400e-03 6.08317100e-03
#  6.06282600e-03 5.47281900e-03 5.12695300e-03 5.58471700e-03
#  5.39143900e-03 4.81160500e-03 4.98453800e-03 4.76074200e-03
#  4.64884400e-03 5.38126600e-03 5.42195600e-03 5.31005900e-03
#  4.55729200e-03 4.20125300e-03 4.15039100e-03 3.89607700e-03
#  3.04158500e-03 2.99072300e-03 2.88899700e-03 2.83813500e-03
#  2.88899700e-03 2.57364900e-03 2.65502900e-03 2.89917000e-03
# ...

# %%
print(classificacao)
print(nomes_caracteristicas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-f93e72956290> in <module>()
# ----> 1 print(classificacao)
#       2 print(nomes_caracteristicas)
#
# NameError: name 'classificacao' is not defined
